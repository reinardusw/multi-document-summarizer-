# %%
import twint

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %%
# !twint "Boko haram" --csv --output none.csv
import asyncio

# def scrape_tweets:
asyncio.set_event_loop(asyncio.new_event_loop())
c = twint.Config()
c.Search = "boko haram"
c.Limit = 100
c.Store_csv = True
c.Lang = "id"
c.Output = "test.csv"
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-22658c2e6f1c> in <module>
#      10 c.Lang = "id"
#      11 c.Output = "test.csv"
# ---> 12 twint.run.Search(c)
#
# D:\ITS\Mata Kuliah\Tugas Akhir\TAFinal\venv\lib\site-packages\twint\run.py in Search(config, callback)
#     283     config.Profile = False
#     284     config.Profile_full = False
# --> 285     run(config, callback)
#     286     if config.Pandas_au:
#     287         storage.panda._autoget("tweet")
#
# D:\ITS\Mata Kuliah\Tugas Akhir\TAFinal\venv\lib\site-packages\twint\run.py in run(config, callback)
#     204 def run(config, callback=None):
#     205     logme.debug(__name__+':run')
# --> 206     get_event_loop().run_until_complete(Twint(config).main(callback))
#     207
#     208 def Favorites(config):
#
# ...

# %%
def my_function(*terms):
    for term in log_progress(terms, every=1):
        print("The youngest child is " + term)        

my_function("Emil", "Tobias", "Linus", "15","Emil", "Tobias", "Linus", "15", "Tobias", "Linus", "15","Emil", "Tobias", "Linus", "15", "Tobias", "Linus", "15","Emil", "Tobias", "Linus", "15", "Tobias", "Linus", "15","Emil", "Tobias", "Linus", "15", "Tobias", "Linus", "15","Emil", "Tobias", "Linus", "15", "Tobias", "Linus", "15","Emil", "Tobias", "Linus", "15")
# Out:
# ...
# The youngest child is Emil
# The youngest child is Tobias
# The youngest child is Linus
# The youngest child is 15
# The youngest child is Emil
# The youngest child is Tobias
# The youngest child is Linus
# The youngest child is 15
# The youngest child is Tobias
# The youngest child is Linus
# The youngest child is 15
# The youngest child is Emil
# The youngest child is Tobias
# The youngest child is Linus
# The youngest child is 15
# The youngest child is Tobias
# The youngest child is Linus
# The youngest child is 15
# The youngest child is Emil
# The youngest child is Tobias
# The youngest child is Linus
# The youngest child is 15
# The youngest child is Tobias
# The youngest child is Linus
# The youngest child is 15
# The youngest child is Emil
# The youngest child is Tobias
# The youngest child is Linus
# The youngest child is 15
# The youngest child is Tobias
# The youngest child is Linus
# The youngest child is 15
# The youngest child is Emil
# The youngest child is Tobias
# ...

# %%
from modulefinder import ModuleFinder
f = ModuleFinder()
# Run the main script
f.run_script('rsummarizer.py')
# Get names of all the imported modules
names = list(f.modules.keys())
# Get a sorted list of the root modules imported
basemods = sorted(set([name.split('.')[0] for name in names]))
# Print it nicely
print ("\n".join(basemods))
# Out:
# ConfigParser
# IPython
# Queue
# SocketServer
# __future__
# __main__
# _ast
# _asyncio
# _bisect
# _blake2
# _bootlocale
# _bz2
# _cffi_backend
# _codecs
# _collections
# _collections_abc
# _compat_pickle
# _compression
# _csv
# _ctypes
# _datetime
# _decimal
# _distutils_findvs
# _dummy_thread
# _elementtree
# _functools
# _hashlib
# _heapq
# _imp
# _io
# _json
# _locale
# _lsprof
# _lzma
# _markupbase
# _md5
# _multiprocessing
# _opcode
# _operator
# _osx_support
# _overlapped
# _pickle
# _pydecimal
# _random
# _sha1
# _sha256
# _sha3
# _sha512
# _signal
# _sitebuiltins
# _socket
# _sqlite3
# _sre
# _ssl
# _stat
# _string
# _strptime
# _struct
# _thread
# _threading_local
# _tkinter
# _tracemalloc
# _warnings
# _weakref
# _weakrefset
# _winapi
# abc
# argparse
# array
# ast
# asyncio
# atexit
# attr
# audioop
# backcall
# base64
# bdb
# binascii
# bisect
# bs4
# builtins
# bz2
# cProfile
# calendar
# cchardet
# certifi
# cffi
# cgi
# chardet
# chunk
# cmd
# code
# codecs
# codeop
# ...
